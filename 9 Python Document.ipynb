# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
# help(requests)

# %%
url = 'http://ergast.com/api/f1/2008/5/driverStandings.json'

# %%
#response object
response = requests.get(url) 
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
# for x in range(5):
#     data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'][x]
# print(data)

my_racer_data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']
data
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '35',
#   'wins': '2',
#   'Driver': {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '28',
#   'wins': '2',
#   'Driver': {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
# ...

# %%
def get_racer_info(data):
    new_data  =   []
    for racer in data:
        racer_dict = {}
        racer_name = f'{racer["Driver"]["givenName"]}{racer["Driver"]["familyName"]}'
        
        racer_dict[racer_name] = {
            'first_name':racer['Driver']['givenName'],
            'last_name':racer['Driver']['familyName'],
            'position':racer['position'],
            'wins':racer['wins'],
            'DOB':racer['Driver']['dateOfBirth'],
            'nationality':racer['Constructors'][0]['name']
        }
        new_data.append(racer_dict)
    return(new_data)
        
get_racer_info(my_racer_data)
# Out:
# [{'KimiRäikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1979-10-17',
#    'nationality': 'Ferrari'}},
#  {'FelipeMassa': {'first_name': 'Felipe',
#    'last_name': 'Massa',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1981-04-25',
#    'nationality': 'Ferrari'}},
#  {'LewisHamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'wins': '1',
#    'DOB': '1985-01-07',
#    'nationality': 'McLaren'}},
#  {'RobertKubica': {'first_name': 'Robert',
#    'last_name': 'Kubica',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1984-12-07',
#    'nationality': 'BMW Sauber'}},
#  {'NickHeidfeld': {'first_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1977-05-10',
#    'nationality': 'BMW Sauber'}},
#  {'HeikkiKovalainen': {'first_name': 'Heikki',
#    'last_name': 'Kovalainen',
#    'position': '6',
#    'wins': '0',
# ...

# %%
def get_driver_info_by_year_and_round(year,r):
    url= f"http://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)

    if not response.json()['MRData']['StandingsTable']['StandingsLists']:
        return "We had an error loading your data"
    data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings']
    return get_racer_info(data)

get_driver_info_by_year_and_round(2019, 4)
# Out:
# [{'ValtteriBottas': {'first_name': 'Valtteri',
#    'last_name': 'Bottas',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1989-08-28',
#    'nationality': 'Mercedes'}},
#  {'LewisHamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1985-01-07',
#    'nationality': 'Mercedes'}},
#  {'SebastianVettel': {'first_name': 'Sebastian',
#    'last_name': 'Vettel',
#    'position': '3',
#    'wins': '0',
#    'DOB': '1987-07-03',
#    'nationality': 'Ferrari'}},
#  {'MaxVerstappen': {'first_name': 'Max',
#    'last_name': 'Verstappen',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1997-09-30',
#    'nationality': 'Red Bull'}},
#  {'CharlesLeclerc': {'first_name': 'Charles',
#    'last_name': 'Leclerc',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1997-10-16',
#    'nationality': 'Ferrari'}},
#  {'SergioPérez': {'first_name': 'Sergio',
#    'last_name': 'Pérez',
#    'position': '6',
#    'wins': '0',
# ...

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 20 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', attack base_state, hp base_stat, defense base_stat

# %%
def pocketMonsters(mon_data, monster):
    url = f"https://pokeapi.co/api/v2/pokemon/{monster}"
    response = requests.get(url)

    if response.status_code != 200:
        print(f"Failed to retreive data. Status Code:{response.status_code}")
        return None
    
    pokemon_data = response.json()
              
              
    monster_info  = []
              
              
    for form in pokemon_data['forms']:
        monster_dict = {}
        abilities = [ability['ability']['name'] for ability in pokemon_data['abilities']]
        stats = {stat['stat']['name']: stat['base_stat'] for stat in pokemon_data['stats']}
        
        
        monster_dict['Pokemon Name'] = form['name'].title()
        
        
        monster_dict['Abilities'] = abilities
        
        
        monster_dict['Base Experience'] = pokemon_data['base_experience']
        monster_dict['Sprite'] = pokemon_data['sprites']['front_shiny']
        
        
        monster_dict['Attack Base Stat'] = stats['attack']
        monster_dict['HP Base Stat'] = stats['hp']
        monster_dict['Defense Base  Stat'] = stats['defense']

        monster_info.append(monster_dict)

    return monster_info


mon_data = []
monster_info = pocketMonsters(mon_data, 'pikachu')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'charmander')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'bulbasaur')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'squirtle')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'pidgey')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'rattata')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'caterpie')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'kakuna')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'weedle')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'abra')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'spearow')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'jigglypuff')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'spearow')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'sandshrew')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'mankey')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'ekans')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'magikarp')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'oddish')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'bellsprout')
print(f'{monster_info} \n')

monster_info = pocketMonsters(mon_data, 'meowth')
print(f'{monster_info} \n')
# Out:
# [{'Pokemon Name': 'Pikachu', 'Abilities': ['static', 'lightning-rod'], 'Base Experience': 112, 'Sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/25.png', 'Attack Base Stat': 55, 'HP Base Stat': 35, 'Defense Base  Stat': 40}]
#
# [{'Pokemon Name': 'Charmander', 'Abilities': ['blaze', 'solar-power'], 'Base Experience': 62, 'Sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/4.png', 'Attack Base Stat': 52, 'HP Base Stat': 39, 'Defense Base  Stat': 43}]
#
# [{'Pokemon Name': 'Bulbasaur', 'Abilities': ['overgrow', 'chlorophyll'], 'Base Experience': 64, 'Sprite': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/1.png', 'Attack Base Stat': 49, 'HP Base Stat': 45, 'Defense Base  Stat': 49}]
#
# ...
